# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import getpass

# Load the CSV file
data = pd.read_csv("data.csv", error_bad_lines=False)
print(data.head())

# Drop rows with missing values
data = data.dropna()

# Map numerical strength values to categorical labels
data["strength"] = data["strength"].map({0: "Weak", 1: "Medium", 2: "Strong"})
print(data.sample(5))

# Define a tokenizer function
def word(password):
    return list(password)

# Extract features and labels
x = np.array(data["password"])
y = np.array(data["strength"])

# Convert passwords to TF-IDF features
tdif = TfidfVectorizer(tokenizer=word)
x = tdif.fit_transform(x)

# Split the data into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.05, random_state=42)

# Train a Random Forest classifier
model = RandomForestClassifier()
model.fit(xtrain, ytrain)

# Evaluate the model
print("Model Accuracy:", model.score(xtest, ytest))

# Prompt the user to enter a password
user = getpass.getpass("Enter Password: ")
data = tdif.transform([user]).toarray()

# Predict the strength of the entered password
output = model.predict(data)
print("Password Strength:", output[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 9
#       6 import getpass
#       8 # Load the CSV file
# ----> 9 data = pd.read_csv("data.csv", error_bad_lines=False)
#      10 print(data.head())
#      12 # Drop rows with missing values
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %%
# Out:
#       password strength Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0     kzde5577        1        NaN        NaN         NaN        NaN
# 1     kino3434        1        NaN        NaN         NaN        NaN
# 2    visi7k1yr        1        NaN        NaN         NaN        NaN
# 3     megzy123        1        NaN        NaN         NaN        NaN
# 4  lamborghin1        1        NaN        NaN         NaN        NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 5
#       1 data = data.dropna()
#       2 data["strength"] = data["strength"].map({0: "Weak",
#       3                                          1: "Medium",
#       4                                          2: "Strong"})
# ----> 5 print(data.sample(5))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5858, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5855 if weights is not None:
#    5856     weights = sample.preprocess_weights(self, weights, axis)
# -> 5858 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5859 result = self.take(sampled_indices, axis=axis)
#    5861 if ignore_index:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\sample.py:151, in sample(obj_len, size, replace, weights, random_state)
#     148     else:
#     149         raise ValueError("Invalid weights: weights sum to zero")
# --> 151 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     152     np.intp, copy=False
#     153 )
#
# File mtrand.pyx:928, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import getpass

# Load the CSV file
data = pd.read_csv("data.csv", on_bad_lines='skip')
print(data.head())

# Drop rows with missing values
data = data.dropna()

# Map numerical strength values to categorical labels
data["strength"] = data["strength"].map({0: "Weak", 1: "Medium", 2: "Strong"})
print(data.sample(5))

# Define a tokenizer function
def word(password):
    return list(password)

# Extract features and labels
x = np.array(data["password"])
y = np.array(data["strength"])

# Convert passwords to TF-IDF features
tdif = TfidfVectorizer(tokenizer=word)
x = tdif.fit_transform(x)

# Split the data into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.05, random_state=42)

# Train a Random Forest classifier
model = RandomForestClassifier()
model.fit(xtrain, ytrain)

# Evaluate the model
print("Model Accuracy:", model.score(xtest, ytest))

# Prompt the user to enter a password
user = getpass.getpass("Enter Password: ")
data = tdif.transform([user]).toarray()

# Predict the strength of the entered password
output = model.predict(data)
print("Password Strength:", output[0])
# Out:
#       password  strength
# 0     kzde5577         1
# 1     kino3434         1
# 2    visi7k1yr         1
# 3     megzy123         1
# 4  lamborghin1         1
#               password strength
# 667541  guseva-liana2X   Strong
# 592261         p4ngs1t     Weak
# 410488          ps2004     Weak
# 259945      DEVILS1994   Medium
# 270091         sofia23     Weak
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
